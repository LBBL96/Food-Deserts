# %%
import pandas as pd
from config import gkey
import numpy as np
import requests
import json

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
infile = pd.read_csv("Dallas_coords.csv")
df = pd.DataFrame(infile)

# %%
df.count()
# Out:
# School Name           142
# Location              142
# Percent in Poverty    142
# Lat                   142
# Long                  142
# Google Place ID       142
# dtype: int64

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# %%
params = {"key": gkey, 
          "location": f"{32.722293},{-96.655593}", 
          "rankby": "distance",
          "type": "grocery_or_supermarket"}

# %%
data = requests.get(base_url, params = params)
# print(data.url)

# %%
closest_grocery = [np.nan]
grocery_address = [np.nan]
school_zip = [np.nan]
grocery_school = pd.DataFrame()

# %%
# grocery_school["School Name"] = names
# grocery_school["Closest Store"] = np.nan
# grocery_school["Store Address"] = np.nan
# grocery_school["Zip Code"] = np.nan
grocery_school["School Address"] = np.nan

# %%
# grocery_school
# show example of grocery_school[14] for google results not jibing with closest store

# %%
grocery_school["School Address"][] = 
grocery_school["Closest Store"][] = 
grocery_school["Store Address"][] =

# %%
names = df['School Name']
grocery_school["Zip Code"][] =

# %%
names[141]
# Out:
# 'Ebby Halliday Elementary School'

# %%
# grocery_school["School Name"][92] = "Robert L. Thornton Elementary School"
# # names[19] = "S S Conner Elementary School"
# grocery_school["Store Address"][21][-5:]

# %%
grocery_school["School Address"][141] = "10210 Teagarden Rd, Dallas, TX 75217"
grocery_school["Closest Store"][141] = "Malone's Cost Plus"
grocery_school["Store Address"][141] = "333 S St Augustine Dr, Dallas, TX 75217"

# %%
grocery_school.count()
# Out:
# School Name       142
# Closest Store     142
# Store Address     142
# Zip Code           23
# School Address    142
# dtype: int64

# %%
# grocery_school.head(2)

# %%
grocery_school.to_csv("Dallas_grocery.csv", index = False)

# %%
# from config import gkey2

# %%
grocery_school.head(10)
# Out:
#                             School Name           Closest Store  \
# 0         William M Anderson Elementary             Fiesta Mart
# 1        Arcadia Park Elementary School  Supermercado Monterrey
# 2      Jose "Joe" May Elementary School             Fiesta Mart
# 3              Bayles Elementary School     Walmart Supercenter
# 4           W A Blair Elementary School             Fiesta Mart
# 5  Annie Webb Blanton Elementary School                    Aldi
# 6         James Bowie Elementary School             Fiesta Mart
# 7    John Neely Bryan Elementary School             Fiesta Mart
# 8        Harrell Budd Elementary School              Save A Lot
# 9     David G. Burnet Elementary School             Fiesta Mart
#
#                             Store Address  Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217   75217.0
# 1       5306 W Davis St, Dallas, TX 75211   75211.0
# 2   9727 Webb Chapel Rd, Dallas, TX 75220   75220.0
# ...

# %%
zip_code = []
school_address = grocery_school["School Address"]

# %%
school_address[0][-5:]
# Out:
# '75217'

# %%
i = 0

while i < len(school_address):
    zip_code.append(school_address[i][-5:])
    i += 1

# %%
grocery_school["Zip Code"] = zip_code

# %%
grocery_school.head(10)
# Out:
#                             School Name           Closest Store  \
# 0         William M Anderson Elementary             Fiesta Mart
# 1        Arcadia Park Elementary School  Supermercado Monterrey
# 2      Jose "Joe" May Elementary School             Fiesta Mart
# 3              Bayles Elementary School     Walmart Supercenter
# 4           W A Blair Elementary School             Fiesta Mart
# 5  Annie Webb Blanton Elementary School                    Aldi
# 6         James Bowie Elementary School             Fiesta Mart
# 7    John Neely Bryan Elementary School             Fiesta Mart
# 8        Harrell Budd Elementary School              Save A Lot
# 9     David G. Burnet Elementary School             Fiesta Mart
#
#                             Store Address Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217    75217
# 1       5306 W Davis St, Dallas, TX 75211    75211
# 2   9727 Webb Chapel Rd, Dallas, TX 75220    75220
# 3     7401 Samuell Blvd, Dallas, TX 75228    75228
# ...

# %%
# Bringing the csv in as a clean file

infile = pd.read_csv("Dallas_grocery.csv")
df = pd.DataFrame(infile)

# %%
df.head(2)
# Out:
#                       School Name           Closest Store  \
# 0   William M Anderson Elementary             Fiesta Mart
# 1  Arcadia Park Elementary School  Supermercado Monterrey
#
#                             Store Address  Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217   75217.0
# 1       5306 W Davis St, Dallas, TX 75211   75211.0
#
#                             School Address
# 0  620 N St Augustine Dr, Dallas, TX 75217
# 1      1300 N Justin Ave, Dallas, TX 75211

# %%
# # Google Distance Matrix API

base_url = "https://maps.googleapis.com/maps/api/distancematrix/json?"

# %%
# params = {
#     "origins": "620 N St Augustine Dr, Dallas, TX 75217", 
#     "key": gkey2, 
#     "destinations": "10121 E Lake June Rd, Dallas, TX 75217", 
#     "units": "imperial"
# }

# # optional to use "mode" = "transit", then "transit_mode" = "bus"

# %%
data = requests.get(base_url, params = params).json()

# %%
# print(json.dumps(data, indent=4))

# %%
print(data["rows"][0]["elements"][0]["distance"]["text"])
# Out:
# 1.4 mi

# %%
distance = data["rows"][0]["elements"][0]["distance"]["text"]

# %%
distance = float(distance[:-3])

# %%
distance
# Out:
# 1.4

# %%
school_address = grocery_school["School Address"]
store_address = grocery_school["Store Address"]

# %%
# school_address = school_address[0:8]
# store_address = store_address[0:8]
# Out:
# 0    10121 E Lake June Rd, Dallas, TX 75217
# 1         5306 W Davis St, Dallas, TX 75211
# 2     9727 Webb Chapel Rd, Dallas, TX 75220
# 3       7401 Samuell Blvd, Dallas, TX 75228
# 4     2951 S Buckner Blvd, Dallas, TX 75227
# 5     2926 S Buckner Blvd, Dallas, TX 75227
# 6    611 W Jefferson Blvd, Dallas, TX 75208
# 7     3030 S Lancaster Rd, Dallas, TX 75216
# Name: Store Address, dtype: object

# %%
# Google Distance Matrix

base_url = "https://maps.googleapis.com/maps/api/distancematrix/json?"

# %%
params = {
    "origins": "620 N St Augustine Dr, Dallas, TX 75217", 
    "key": gkey2, 
    "destinations": "10121 E Lake June Rd, Dallas, TX 75217", 
    "units": "imperial"
}

# %%
# data = requests.get(base_url, params = params).json()

# %%
walking_distance = []
i = 0

while i < len(school_address):
    
    params = {
    "origins": school_address[i], 
    "key": gkey2, 
    "destinations": store_address[i], 
    "units": "imperial",
    "mode": "walking"}
    
    data = requests.get(base_url, params = params).json()
    
    temp = data["rows"][0]["elements"][0]["distance"]["text"]
    walking_distance.append(float(temp[:-3]))
    
    i += 1

# %%
len(walking_distance)
# Out:
# 142

# %%
df["Walking Distance (miles)"] = walking_distance

# %%
df.head()
# Out:
#                         School Name           Closest Store  \
# 0     William M Anderson Elementary             Fiesta Mart
# 1    Arcadia Park Elementary School  Supermercado Monterrey
# 2  Jose "Joe" May Elementary School             Fiesta Mart
# 3          Bayles Elementary School     Walmart Supercenter
# 4       W A Blair Elementary School             Fiesta Mart
#
#                             Store Address  Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217   75217.0
# 1       5306 W Davis St, Dallas, TX 75211   75211.0
# 2   9727 Webb Chapel Rd, Dallas, TX 75220   75220.0
# 3     7401 Samuell Blvd, Dallas, TX 75228   75228.0
# 4   2951 S Buckner Blvd, Dallas, TX 75227   75217.0
#
#                             School Address  Walking Distance
# 0  620 N St Augustine Dr, Dallas, TX 75217               1.2
# 1      1300 N Justin Ave, Dallas, TX 75211               0.9
# 2      9818 Brockbank Dr, Dallas, TX 75220               1.3
# ...

# %%
driving_distance = []
i = 0

while i < len(school_address):
    
    params = {
    "origins": school_address[i], 
    "key": gkey2, 
    "destinations": store_address[i], 
    "units": "imperial"}
    
    data = requests.get(base_url, params = params).json()
    
    temp = data["rows"][0]["elements"][0]["distance"]["text"]
    driving_distance.append(float(temp[:-3]))
    
    i += 1

# %%
len(driving_distance)
# Out:
# 142

# %%
df["Driving Distance (miles)"] = driving_distance

# %%
df = df.drop("Walking Distance", axis = 1)

# %%
df.count()
# Out:
# School Name                 142
# Closest Store               142
# Store Address               142
# Zip Code                     23
# School Address              142
# Walking Distance (miles)    142
# Driving Distance (miles)    142
# dtype: int64

# %%
# bus_distance = []
# i = 0

# while i < len(school_address):

#     params = {
#     "origins": school_address[i], 
#     "key": gkey2, 
#     "destinations": store_address[i], 
#     "units": "imperial",
#     "mode": "transit",
#     "transit_mode": "bus"}

#     data = requests.get(base_url, params = params).json()

#     temp = data["rows"][0]["elements"][0]["distance"]["text"]
#     bus_distance.append(float(temp[:-3]))
    
#     i += 1

# %%
# data["rows"][0]["elements"][0]["distance"]["text"]

# %%
bus_distance
# Out:
# [1.4, 0.9, 1.7, 2.1, 4.2, 2.2, 2.0, 0.7, 0.9, 0.7, 6.4, 3.4]

# %%
df.head()
# Out:
#                         School Name           Closest Store  \
# 0     William M Anderson Elementary             Fiesta Mart
# 1    Arcadia Park Elementary School  Supermercado Monterrey
# 2  Jose "Joe" May Elementary School             Fiesta Mart
# 3          Bayles Elementary School     Walmart Supercenter
# 4       W A Blair Elementary School             Fiesta Mart
#
#                             Store Address  Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217   75217.0
# 1       5306 W Davis St, Dallas, TX 75211   75211.0
# 2   9727 Webb Chapel Rd, Dallas, TX 75220   75220.0
# 3     7401 Samuell Blvd, Dallas, TX 75228   75228.0
# 4   2951 S Buckner Blvd, Dallas, TX 75227   75217.0
#
#                             School Address  Walking Distance (miles)  \
# 0  620 N St Augustine Dr, Dallas, TX 75217                       1.2
# 1      1300 N Justin Ave, Dallas, TX 75211                       0.9
# 2      9818 Brockbank Dr, Dallas, TX 75220                       1.3
# ...

# %%
df.count()
# Out:
# School Name                 142
# Closest Store               142
# Store Address               142
# Zip Code                     23
# School Address              142
# Walking Distance (miles)    142
# Driving Distance (miles)    142
# dtype: int64

# %%
len(zip_code)
# Out:
# 142

# %%
df["Zip Code"] = zip_code

# %%
df.to_csv("Dallas Distances.csv", index = False)

# %%
df.head(2)
# Out:
#                       School Name           Closest Store  \
# 0   William M Anderson Elementary             Fiesta Mart
# 1  Arcadia Park Elementary School  Supermercado Monterrey
#
#                             Store Address Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217    75217
# 1       5306 W Davis St, Dallas, TX 75211    75211
#
#                             School Address  Walking Distance (miles)  \
# 0  620 N St Augustine Dr, Dallas, TX 75217                       1.2
# 1      1300 N Justin Ave, Dallas, TX 75211                       0.9
#
#    Driving Distance (miles)
# 0                       1.4
# 1                       0.9

# %%
df["Location"] = "Dallas"

# %%
df.head(2)
# Out:
#                       School Name           Closest Store  \
# 0   William M Anderson Elementary             Fiesta Mart
# 1  Arcadia Park Elementary School  Supermercado Monterrey
#
#                             Store Address Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217    75217
# 1       5306 W Davis St, Dallas, TX 75211    75211
#
#                             School Address  Walking Distance (miles)  \
# 0  620 N St Augustine Dr, Dallas, TX 75217                       1.2
# 1      1300 N Justin Ave, Dallas, TX 75211                       0.9
#
#    Driving Distance (miles) Location
# 0                       1.4   Dallas
# 1                       0.9   Dallas

# %%
df2 = df[["School Name", "Location", "Closest Store", "Store Address", "Driving Distance (miles)", "Walking Distance (miles)", "Zip Code"]]

# %%
df2.head(2)
# Out:
#                       School Name Location           Closest Store  \
# 0   William M Anderson Elementary   Dallas             Fiesta Mart
# 1  Arcadia Park Elementary School   Dallas  Supermercado Monterrey
#
#                             Store Address  Driving Distance (miles)  \
# 0  10121 E Lake June Rd, Dallas, TX 75217                       1.4
# 1       5306 W Davis St, Dallas, TX 75211                       0.9
#
#    Walking Distance (miles) Zip Code
# 0                       1.2    75217
# 1                       0.9    75211

# %%
infile = pd.read_csv("Dallas_coords.csv")
df_to_merge = pd.DataFrame(infile)

# %%
df_to_merge.head()
# Out:
#                         School Name Location  Percent in Poverty        Lat  \
# 0     William M Anderson Elementary   Dallas               97.13  32.722293
# 1    Arcadia Park Elementary School   Dallas               96.33  32.759033
# 2  Jose "Joe" May Elementary School   Dallas               96.24  32.871896
# 3          Bayles Elementary School   Dallas               98.00  32.800938
# 4       W A Blair Elementary School   Dallas               86.67  32.708937
#
#         Long              Google Place ID
# 0 -96.655593  ChIJCbZ4NlO7ToYRv7DYsyn6ETw
# 1 -96.910502  ChIJqe794iWbToYRjwbEYrqUy68
# 2 -96.875018  ChIJn_6JKTadToYROcaO8wodk6c
# 3 -96.706953  ChIJW0n6KS2iToYRr3_cVUo--SE
# 4 -96.689292  ChIJiUIVoci8ToYRCk6ojehYKI0

# %%
poverty = df_to_merge["Percent in Poverty"]

# %%
df2["Percent in Poverty"] = poverty

# %%
df2 = df2[["School Name", "Location", "Closest Store", "Store Address", "Driving Distance (miles)", "Walking Distance (miles)", "Percent in Poverty", "Zip Code"]]

# %%
df2.head()
# Out:
#                         School Name Location           Closest Store  \
# 0     William M Anderson Elementary   Dallas             Fiesta Mart
# 1    Arcadia Park Elementary School   Dallas  Supermercado Monterrey
# 2  Jose "Joe" May Elementary School   Dallas             Fiesta Mart
# 3          Bayles Elementary School   Dallas     Walmart Supercenter
# 4       W A Blair Elementary School   Dallas             Fiesta Mart
#
#                             Store Address  Driving Distance (miles)  \
# 0  10121 E Lake June Rd, Dallas, TX 75217                       1.4
# 1       5306 W Davis St, Dallas, TX 75211                       0.9
# 2   9727 Webb Chapel Rd, Dallas, TX 75220                       1.7
# 3     7401 Samuell Blvd, Dallas, TX 75228                       1.5
# 4   2951 S Buckner Blvd, Dallas, TX 75227                       4.1
#
#    Walking Distance (miles)  Percent in Poverty Zip Code
# 0                       1.2               97.13    75217
# ...

# %%
df2.to_csv("Dallas_Distances.csv", index = False)

# %%
from config import gkey2

# %%
import pandas as pd
import numpy as np

# %%
infile = pd.read_csv("Dallas_Distances.csv")
df = pd.DataFrame(infile)

# %%
df.head(2)
# Out:
#                       School Name Location           Closest Store  \
# 0   William M Anderson Elementary   Dallas             Fiesta Mart
# 1  Arcadia Park Elementary School   Dallas  Supermercado Monterrey
#
#                             Store Address  Driving Distance (miles)  \
# 0  10121 E Lake June Rd, Dallas, TX 75217                       1.4
# 1       5306 W Davis St, Dallas, TX 75211                       0.9
#
#    Walking Distance (miles)  Percent in Poverty  Zip Code
# 0                       1.2               97.13     75217
# 1                       0.9               96.33     75211

# %%
base_url = "https://maps.googleapis.com/maps/api/distancematrix/json?"

# %%
bus_distance = []

params = {
"origins": "620 N St Augustine Dr, Dallas, TX 75217", 
"key": gkey2, 
"destinations": "10121 E Lake June Rd, Dallas, TX 75217", 
"units": "imperial",
"mode": "transit",
"transit_mode": "bus"}

data = requests.get(base_url, params = params)

print(data.url)
# Out:
# https://maps.googleapis.com/maps/api/distancematrix/json?origins=620+N+St+Augustine+Dr%2C+Dallas%2C+TX+75217&key=AIzaSyArTeKsObRK8zpdzKsowzhaX1YwByYPVTA&destinations=10121+E+Lake+June+Rd%2C+Dallas%2C+TX+75217&units=imperial&mode=transit&transit_mode=bus

# %%
infile = pd.read_csv("Dallas_grocery.csv")
df2 = pd.DataFrame(infile)

# %%
df2.head(2)
# Out:
#                       School Name           Closest Store  \
# 0   William M Anderson Elementary             Fiesta Mart
# 1  Arcadia Park Elementary School  Supermercado Monterrey
#
#                             Store Address  Zip Code  \
# 0  10121 E Lake June Rd, Dallas, TX 75217   75217.0
# 1       5306 W Davis St, Dallas, TX 75211   75211.0
#
#                             School Address
# 0  620 N St Augustine Dr, Dallas, TX 75217
# 1      1300 N Justin Ave, Dallas, TX 75211

# %%
bus_distance = []

params = {
"origins": "1300 N Justin Ave, Dallas, TX 75211", 
"key": gkey2, 
"destinations": "5306 W Davis St, Dallas, TX 75211", 
"units": "imperial",
"mode": "transit",
"transit_mode": "bus"}

data = requests.get(base_url, params = params)

print(data.url)
# Out:
# https://maps.googleapis.com/maps/api/distancematrix/json?origins=1300+N+Justin+Ave%2C+Dallas%2C+TX+75211&key=AIzaSyArTeKsObRK8zpdzKsowzhaX1YwByYPVTA&destinations=5306+W+Davis+St%2C+Dallas%2C+TX+75211&units=imperial&mode=transit&transit_mode=bus

# %%
school_address = df2["School Address"]
store_address = df2["Store Address"]

# %%
bus_distance = []
i = 0

while i < 142:    
  

    params = {
    "origins": school_address[i], 
    "key": gkey2, 
    "destinations": store_address[i], 
    "units": "imperial",
    "mode": "transit",
    "transit_mode": "bus"}

    data = requests.get(base_url, params = params).json()
    
    try:

        temp = data["rows"][0]["elements"][0]["distance"]["text"]
        bus_distance.append(float(temp[:-3]))
    except:
        print("not available")
    
    i += 1

# %%
bus_distance[22]
# Out:
# 495.0

# %%
drive_distance = df["Driving Distance (miles)"]

# %%
drive_distance[:10]
# Out:
# 0    1.4
# 1    0.9
# 2    1.7
# 3    1.5
# 4    4.1
# 5    1.6
# 6    1.5
# 7    0.6
# 8    0.9
# 9    0.8
# Name: Driving Distance (miles), dtype: float64

# %%
df.count()
# Out:
# School Name                 142
# Location                    142
# Closest Store               142
# Store Address               142
# Driving Distance (miles)    142
# Walking Distance (miles)    142
# Percent in Poverty          142
# Zip Code                    142
# dtype: int64

# %%
df["Bus Distance (miles)"] = bus_distance

# %%
df.count()
# Out:
# School Name                 142
# Location                    142
# Closest Store               142
# Store Address               142
# Driving Distance (miles)    142
# Walking Distance (miles)    142
# Percent in Poverty          142
# Zip Code                    142
# Bus Distance (miles)        142
# dtype: int64

# %%
df.head(23)
# Out:
#                                School Name Location  \
# 0            William M Anderson Elementary   Dallas
# 1           Arcadia Park Elementary School   Dallas
# 2         Jose "Joe" May Elementary School   Dallas
# 3                 Bayles Elementary School   Dallas
# 4              W A Blair Elementary School   Dallas
# 5     Annie Webb Blanton Elementary School   Dallas
# 6            James Bowie Elementary School   Dallas
# 7       John Neely Bryan Elementary School   Dallas
# 8           Harrell Budd Elementary School   Dallas
# 9        David G. Burnet Elementary School   Dallas
# 10      Rufus C Burleson Elementary School   Dallas
# 11           W W Bushman Elementary School   Dallas
# 12          Chapel Hill Preparatory School   Dallas
# 13         F. P. Caillet Elementary School   Dallas
# 14      John W Carpenter Elementary School   Dallas
# 15              C F Carr Elementary School   Dallas
# 16             Casa View Elementary School   Dallas
# ...

# %%
495/5280
# Out:
# 0.09375

# %%
df["Driving Distance (miles)"][22] = 0.09

# %%
df["Walking Distance (miles)"][22] = 0.09

# %%
df["Bus Distance (miles)"][22] = 0.09

# %%
df.head(23)
# Out:
#                                School Name Location  \
# 0            William M Anderson Elementary   Dallas
# 1           Arcadia Park Elementary School   Dallas
# 2         Jose "Joe" May Elementary School   Dallas
# 3                 Bayles Elementary School   Dallas
# 4              W A Blair Elementary School   Dallas
# 5     Annie Webb Blanton Elementary School   Dallas
# 6            James Bowie Elementary School   Dallas
# 7       John Neely Bryan Elementary School   Dallas
# 8           Harrell Budd Elementary School   Dallas
# 9        David G. Burnet Elementary School   Dallas
# 10      Rufus C Burleson Elementary School   Dallas
# 11           W W Bushman Elementary School   Dallas
# 12          Chapel Hill Preparatory School   Dallas
# 13         F. P. Caillet Elementary School   Dallas
# 14      John W Carpenter Elementary School   Dallas
# 15              C F Carr Elementary School   Dallas
# 16             Casa View Elementary School   Dallas
# ...

# %%
df.head(2)
# Out:
#                       School Name Location           Closest Store  \
# 0   William M Anderson Elementary   Dallas             Fiesta Mart
# 1  Arcadia Park Elementary School   Dallas  Supermercado Monterrey
#
#                             Store Address  Driving Distance (miles)  \
# 0  10121 E Lake June Rd, Dallas, TX 75217                       1.4
# 1       5306 W Davis St, Dallas, TX 75211                       0.9
#
#    Walking Distance (miles)  Percent in Poverty  Zip Code  \
# 0                       1.2               97.13     75217
# 1                       0.9               96.33     75211
#
#    Bus Distance (miles)
# 0                   1.4
# 1                   0.9

# %%
df3 = df[["School Name", "Location", "Closest Store", "Store Address", "Driving Distance (miles)", "Bus Distance (miles)", "Walking Distance (miles)", "Percent in Poverty", "Zip Code"]]

# %%
df3.head(2)
# Out:
#                       School Name Location           Closest Store  \
# 0   William M Anderson Elementary   Dallas             Fiesta Mart
# 1  Arcadia Park Elementary School   Dallas  Supermercado Monterrey
#
#                             Store Address  Driving Distance (miles)  \
# 0  10121 E Lake June Rd, Dallas, TX 75217                       1.4
# 1       5306 W Davis St, Dallas, TX 75211                       0.9
#
#    Bus Distance (miles)  Walking Distance (miles)  Percent in Poverty  \
# 0                   1.4                       1.2               97.13
# 1                   0.9                       0.9               96.33
#
#    Zip Code
# 0     75217
# 1     75211

# %%
df3.to_csv("Dallas_Distances.csv", index = False)

# %%
infile = pd.read_csv("Dallas_Distances.csv")
df = pd.DataFrame(infile)

# %%
df.head(3)
# Out:
#                         School Name Location           Closest Store  \
# 0     William M Anderson Elementary   Dallas             Fiesta Mart
# 1    Arcadia Park Elementary School   Dallas  Supermercado Monterrey
# 2  Jose "Joe" May Elementary School   Dallas             Fiesta Mart
#
#                             Store Address  Driving Distance (miles)  \
# 0  10121 E Lake June Rd, Dallas, TX 75217                       1.4
# 1       5306 W Davis St, Dallas, TX 75211                       0.9
# 2   9727 Webb Chapel Rd, Dallas, TX 75220                       1.7
#
#    Bus Distance (miles)  Walking Distance (miles)  Percent in Poverty  \
# 0                   1.4                       1.2               97.13
# 1                   0.9                       0.9               96.33
# 2                   1.7                       1.3               96.24
#
#    Zip Code
# 0     75217
# 1     75211
# 2     75220

# %%
df.groupby("Closest Store").agg({"Driving Distance (miles)":"mean", "Bus Distance (miles)":"mean", "Walking Distance (miles)":"mean"})
# Out:
#                                Driving Distance (miles)  Bus Distance (miles)  \
# Closest Store
# Albertsons                                     1.800000              1.700000
# Aldi                                           1.164286              1.400000
# Cash Saver                                     1.100000              1.200000
# Cox Farms Market - Dallas                      0.950000              1.150000
# El Rancho Supermercado                         0.940000              1.010000
# El Rio Grande Latin Market                     1.000000              0.900000
# Elrod's Cost Plus Supermarket                  1.400000              1.400000
# Fiesta Mart                                    1.580556              1.969444
# Grocery Clearance Center                       1.700000              2.550000
# Jerry's Supermarket                            2.350000              2.600000
# Kroger                                         1.280000              1.280000
# ...
